# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("params_runs.csv")
y = df["value"]
data = df.drop(["state", "number", 
             "datetime_start", "datetime_complete",
             "duration"], axis=1)
X = data.drop(["value"], axis=1)

# %% [markdown]
# #### Correlation $\rightarrow$ Importance of the parameters

# %%
corr = data.corr()["value"].drop(["value"]).abs()

fig, ax = plt.subplots()
plt.title("Hyper parameters importances")
rects = ax.bar(range(len(corr)), corr)
keys = corr.keys()
for i, rect in enumerate(rects):
    ax.annotate('{}'.format(keys[i][7:]),
                xy=(rect.get_x() + rect.get_width() / 2, corr[keys[i]]),
                xytext=(0, 1),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom')

# %%
plt.xscale('log')
plt.plot(X["params_bias_mutate_power"], y, "x")
plt.xlabel("bias_mutate_power")
plt.ylabel("Fitness")
# Out:
# Text(0, 0.5, 'Fitness')

# %%
plt.xscale('log')
plt.plot(X["params_weight_mutate_power"], y, "x")
plt.xlabel("weight_mutate_power")
plt.ylabel("Fitness")
# Out:
# Text(0, 0.5, 'Fitness')

# %%
plt.plot(X["params_node_add_prob"], y, "x")
plt.xlabel("node_add_prob")
plt.ylabel("Fitness")
# Out:
# Text(0, 0.5, 'Fitness')

# %%
plt.plot(X["params_pop_size"], y, "x")
plt.xlabel("pop_size")
plt.ylabel("Fitness")
# Out:
# Text(0, 0.5, 'Fitness')
